# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
iris=pd.read_csv("/iris.csv")
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#get the information about data set
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# show rows and column
iris.shape
# Out:
# (150, 5)

# %%
#statistics of data set
iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # **Disribution in bars plot**

# %%
sns.barplot(iris)
# Out:
# <Axes: >

# %%
sns.barplot(x="Sepal.Length", hue="Species", data=iris)
plt.show()

# %%
sns.barplot(x="Sepal.Width", hue="Species", data=iris)
plt.show()

# %%
sns.barplot(x="Petal.Length", hue="Species", data=iris)
plt.show()

# %%
sns.barplot(x="Petal.Width", hue="Species", data=iris)
plt.show()

# %% [markdown]
# # **Distribution in histogram plot **

# %%
sns.histplot(iris)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data=iris, hue="Species",y="Petal.Width",discrete=True)
plt.show()

# %%
sns.histplot(data=iris, hue="Species",y="Petal.Length", discrete=True)
plt.show()

# %%
sns.histplot(data=iris, hue="Species",y="Sepal.Width", discrete=True)
plt.show()

# %%
sns.histplot(data=iris, hue="Species",y="Sepal.Length", discrete=True)
plt.show()
